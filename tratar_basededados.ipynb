# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./cyberbullying_forms.xlsx')

df.head()
# Out:
#            Carimbo de data/hora Qual  seu gênero? Qual é a sua idade?  \
# 0  2023/05/23 10:27:41 PM GMT-3         Masculino  Entre 18 a 30 anos
# 1  2023/05/23 10:33:44 PM GMT-3         Masculino  Entre 18 a 30 anos
# 2  2023/05/23 10:34:34 PM GMT-3         Masculino  Entre 18 a 30 anos
# 3  2023/05/23 10:35:16 PM GMT-3         Masculino  Entre 18 a 30 anos
# 4   2023/05/24 6:57:40 AM GMT-3         Masculino  Entre 18 a 30 anos
#
#   Qual faixa etária de pessoas é mais vulnerável ao cyberbullying?  \
# 0                                      Entre 15 a 18
# 1                                      Entre 15 a 18
# 2                                  Abaixo de 15 anos
# 3                                  Abaixo de 15 anos
# 4                              Entre de 30 a 60 anos
#
#   Você já foi vítima de cyberbullying?  \
# 0                                  Não
# 1                                  Sim
# 2                               Talvez
# 3                                  Não
# ...

# %%
df = df.drop(columns=['Carimbo de data/hora'])

# %%
df.head()
# Out:
#   Qual  seu gênero? Qual é a sua idade?  \
# 0         Masculino  Entre 18 a 30 anos
# 1         Masculino  Entre 18 a 30 anos
# 2         Masculino  Entre 18 a 30 anos
# 3         Masculino  Entre 18 a 30 anos
# 4         Masculino  Entre 18 a 30 anos
#
#   Qual faixa etária de pessoas é mais vulnerável ao cyberbullying?  \
# 0                                      Entre 15 a 18
# 1                                      Entre 15 a 18
# 2                                  Abaixo de 15 anos
# 3                                  Abaixo de 15 anos
# 4                              Entre de 30 a 60 anos
#
#   Você já foi vítima de cyberbullying?  \
# 0                                  Não
# 1                                  Sim
# 2                               Talvez
# 3                                  Não
# 4                               Talvez
#
#              Se sim, como você lidou com isso?  \
# 0                                          NaN
# ...

# %%
df.groupby('Qual plataforma, na sua opinião, lidera o cyberbullying?').size().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: >

# %%
df.groupby('Você já agrediu alguém na internet de forma consciente ou inconsciente?').size().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: >

# %%
#sns.catplot(x='Você já agrediu alguém na internet de forma consciente ou inconsciente?' , kind='count',data=df , hue="Qual seu gênero?")

# %%
#sns.lineplot(x = 'Qual seu gênero?', y = 'Qual plataforma, na sua opinião, lidera o cyberbullying?', data = df, marker='o', markersize=12, linewidth=2)

# %%
#sns.barplot(data=df, x="Qual seu gênero?", kind='count')

# %%
#fig, ax = plt.subplots(figsize=(16,12))
sns.catplot(x='Qual tem mais impacto em um indivíduo, o cyberbullying ou o bullying na vida real?' , kind='count',data=df, aspect = 2)
